# %%
import pandas as pd

# %%
class Manager:
    def __init__(self,file:str,  sheet:str):
        self.data = pd.read_excel(file, sheet_name=sheet)
        
    
    def loc(self):
        pass

# %%
products = Manager('products.xlsx', 'Products')
proData = products.data

# %%
proData.loc[(proData.quantityInStock <= 5000)&(proData.buyPrice >= 100)]
# Out:
#    productCode                     productName   productLine productScale  \
# 25    S18_2238  1998 Chrysler Plymouth Prowler  Classic Cars         1:18
#
#            productVendor                                 productDescription  \
# 25  Gearbox Collectibles  Turnable front wheels, steering function, deta...
#
#     quantityInStock  buyPrice    MSRP
# 25             4724    101.51  163.73

# %%
proData.loc[(proData.quantityInStock <= 5000)&(proData.buyPrice <= 100)]
# Out:
#     productCode                                  productName  \
# 4      S10_4757                          1972 Alfa Romeo GTA
# 6      S12_1099                            1968 Ford Mustang
# 7      S12_1108                            2001 Ferrari Enzo
# 8      S12_1666                               1958 Setra Bus
# 12     S12_3891                             1969 Ford Falcon
# 16     S18_1097                       1940 Ford Pickup Truck
# 17     S18_1129                              1993 Mazda RX-7
# 22     S18_1749                     1917 Grand Touring Sedan
# 26     S18_2248                           1911 Ford Town Car
# 29     S18_2432                        1926 Ford Fire Engine
# 30     S18_2581                               P-51-D Mustang
# 31     S18_2625          1936 Harley Davidson El Knucklehead
# 32     S18_2795                       1928 Mercedes-Benz SSK
# 34     S18_2949                  1913 Ford Model T Speedster
# ...

# %%
oder = pd.concat([Manager('products.xlsx', 'Orders').data, Manager('products.xlsx', 'orderDetails').data], axis=1)

# %%
oder.loc[(oder.status == 'Shipped')]
# Out:
#      orderNumber            orderDate         requiredDate  \
# 0        10100.0  2003-01-06 00:00:00  2003-01-13 00:00:00
# 1        10101.0  2003-01-09 00:00:00  2003-01-18 00:00:00
# 2        10102.0  2003-01-10 00:00:00  2003-01-18 00:00:00
# 3        10103.0  2003-01-29 00:00:00  2003-02-07 00:00:00
# 4        10104.0  2003-01-31 00:00:00  2003-02-09 00:00:00
# ..           ...                  ...                  ...
# 312      10412.0  2005-05-03 00:00:00  2005-05-13 00:00:00
# 313      10413.0  2005-05-05 00:00:00  2005-05-14 00:00:00
# 316      10416.0  2005-05-10 00:00:00  2005-05-16 00:00:00
# 318      10418.0  2005-05-16 00:00:00  2005-05-24 00:00:00
# 319      10419.0  2005-05-17 00:00:00  2005-05-28 00:00:00
#
#              shippedDate   status  \
# 0    2003-01-10 00:00:00  Shipped
# 1    2003-01-11 00:00:00  Shipped
# 2    2003-01-14 00:00:00  Shipped
# 3    2003-02-02 00:00:00  Shipped
# 4    2003-02-01 00:00:00  Shipped
# ..                   ...      ...
# ...
